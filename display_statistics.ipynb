# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
losses = pd.read_csv("task_1/lesses.csv", index_col=0)

# %%
losses.drop("latten_dist", axis=1).plot()
losses.drop("losses", axis=1).plot()
# Out:
# <Axes: >
